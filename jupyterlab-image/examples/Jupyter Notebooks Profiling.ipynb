# %% [markdown]
# # Jupyter Notebooks Profiling
#
# For original article, see:
#
# https://towardsdatascience.com/speed-up-jupyter-notebooks-20716cbe2025

# %%
from random import random

def estimate_pi(n=1e3):
    """Estimate pi with monte carlo simulation.
    
    Arguments:
        n: number of simulations
    """
    in_circle = 0
    total = n
    
    while n != 0:
        prec_x = random()
        prec_y = random()
        if pow(prec_x, 2) + pow(prec_y, 2) <= 1:
            in_circle += 1 # inside the circle
        n -= 1
        
    return 4 * in_circle / total

# %%
# %time estimate_pi()
# Out:
# CPU times: user 742 µs, sys: 114 µs, total: 856 µs
# Wall time: 859 µs
# 3.132

# %%
# %timeit -r 2 -n 5 estimate_pi()
# Out:
# 628 µs ± 7.09 µs per loop (mean ± std. dev. of 2 runs, 5 loops each)

# %%
# %prun estimate_pi()

# %%
# %load_ext line_profiler

# %%
# %lprun -f estimate_pi estimate_pi()

# %%
# %load_ext heat

# %%
# %%heat
# from random import random
#
# def estimate_pi(n=1e3):
#     """Estimate pi with monte carlo simulation.
#
#     Arguments:
#         n: number of simulations
#     """
#     in_circle = 0
#     total = n
#
#     while n != 0:
#         prec_x = random()
#         prec_y = random()
#         if pow(prec_x, 2) + pow(prec_y, 2) <= 1:
#             in_circle += 1 # inside the circle
#         n -= 1
#
#     return 4 * in_circle / total
# estimate_pi()
# Out:
# /home/mikc/.local/lib/python3.8/site-packages/pyheat/pyheat.py:158: UserWarning: FixedFormatter should only be used together with FixedLocator
#   self.ax.set_yticklabels(row_labels, minor=False)
